# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathesh55/Mathesh/blob/main/Pandas_beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([10,12,13,44,56])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    12
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
s[3]
# Out:
# 44

# %%
s.drop(3)
# Out:
# 0    10
# 1    12
# 2    13
# 4    56
# dtype: int64

# %%
s.loc[4]
# Out:
# 56

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ss=pd.Series([10,12,13,44,56],index=['a','b','c','d','e'])
ss
# Out:
# a    10
# b    12
# c    13
# d    44
# e    56
# dtype: int64

# %%
ss.iloc[3]
# Out:
# 44

# %%
data=[['Alex',10,'23-05-2000'],['Bob',None,None],['Clarke',None,'16-03-2004']]
data[2]
# Out:
# ['Clarke', None, '16-03-2004']

# %%
df=pd.DataFrame(data)
df
# Out:
#         0     1           2
# 0    Alex  10.0  23-05-2000
# 1     Bob   NaN        None
# 2  Clarke   NaN  16-03-2004

# %%
df[0:1]
# Out:
#       0     1           2
# 0  Alex  10.0  23-05-2000

# %%
df[0:2]
# Out:
#       0     1           2
# 0  Alex  10.0  23-05-2000
# 1   Bob   NaN        None

# %%
df[1:2]
# Out:
#      0   1     2
# 1  Bob NaN  None

# %%
df[0][0]
# Out:
# 'Alex'

# %%
df[[0,1]]
# Out:
#         0     1
# 0    Alex  10.0
# 1     Bob   NaN
# 2  Clarke   NaN

# %%
df[0]
# Out:
# 0      Alex
# 1       Bob
# 2    Clarke
# Name: 0, dtype: object

# %%
df=pd.DataFrame(data,columns=['First name','Age','DOB'])
df
# Out:
#   First name   Age         DOB
# 0       Alex  10.0  23-05-2000
# 1        Bob   NaN        None
# 2     Clarke   NaN  16-03-2004

# %%
df['Age']
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
df['First name'][0]
# Out:
# 'Alex'

# %%
df.loc[0,'First name']
# Out:
# 'Alex'

# %%
df.iloc[:1]
# Out:
#   First name   Age         DOB
# 0       Alex  10.0  23-05-2000

# %%
df[:1]
# Out:
#   First name   Age         DOB
# 0       Alex  10.0  23-05-2000

# %%
s=pd.Series([1,2,3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy()
type(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-09c8072e040a> in <cell line: 1>()
# ----> 1 s.to_numpy()
#       2 type(s)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
df.head(1)
# Out:
#   First name   Age         DOB
# 0       Alex  10.0  23-05-2000

# %%
df.tail(-2)
# Out:
#   First name  Age         DOB
# 2     Clarke  NaN  16-03-2004

# %%
# None,' ','','-','?','Nil',np.nan(not a number)

# %%
df
# Out:
#   First name   Age         DOB
# 0       Alex  10.0  23-05-2000
# 1        Bob   NaN        None
# 2     Clarke   NaN  16-03-2004

# %%
df.isnull().sum()
# Out:
# First name    0
# Age           2
# DOB           1
# dtype: int64

# %%
data=[['Alex',np.nan,'?'],['Bob',None,None],['Clarke',None,'']]
df=pd.DataFrame(data,columns=['First name','Age','DOB'])
df
# Out:
#   First name  Age   DOB
# 0       Alex  NaN     ?
# 1        Bob  NaN  None
# 2     Clarke  NaN

# %%
df.isnull().sum()
# Out:
# First name    0
# Age           3
# DOB           1
# dtype: int64

# %%
df.drop(['Age'],axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-10abf17a3e90> in <cell line: 1>()
# ----> 1 df.drop(['Age'],axis=1,inplace=True)
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df.drop([0,2])
# Out:
#   First name   DOB
# 1        Bob  None

# %%
a=np.array([10,20,30,40,50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
a>40
# Out:
# array([False, False, False, False,  True])

# %%
a[a>40]
# Out:
# array([50])

# %%
a[a%2!=0]
# Out:
# array([], dtype=int64)

# %%
df
# Out:
#   First name   DOB
# 0       Alex     ?
# 1        Bob  None
# 2     Clarke

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First name  3 non-null      object
#  1   DOB         2 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
df['First name'].str.contains('e')
# Out:
# 0     True
# 1    False
# 2     True
# Name: First name, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 2)
# 6
# [RangeIndex(start=0, stop=3, step=1), Index(['First name', 'DOB'], dtype='object')]
# 2
# First name    object
# DOB           object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['First name', 'DOB'], dtype='object')
# [['Alex' '?']
#  ['Bob' None]
#  ['Clarke' '']]

# %%
df2=pd.concat([df,df])
df2
# Out:
#   First name   DOB
# 0       Alex     ?
# 1        Bob  None
# 2     Clarke
# 0       Alex     ?
# 1        Bob  None
# 2     Clarke

# %%
df.describe()
# Out:
#        First name DOB
# count           3   2
# unique          3   2
# top          Alex   ?
# freq            1   1

# %%
df['First name']
# Out:
# 0      Alex
# 1       Bob
# 2    Clarke
# Name: First name, dtype: object

# %%
df.DOB
# Out:
# 0       ?
# 1    None
# 2
# Name: DOB, dtype: object

# %%
df[['First name','DOB']]
# Out:
#   First name   DOB
# 0       Alex     ?
# 1        Bob  None
# 2     Clarke

# %%
df.loc[0][0]
# Out:
# 'Alex'

# %%
df.loc[0,'First name']
# Out:
# 'Alex'

# %%
df.iloc[0,1]
# Out:
# '?'

# %%
df["DOB"][1]='30-3-2004'

# %%
df
# Out:
#   First name        DOB
# 0       Alex          ?
# 1        Bob  30-3-2004
# 2     Clarke

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
df
# Out:
# [    Rank  Peak                                          Title  \
#  0      1     1                                         Avatar
#  1      2     1                              Avengers: Endgame
#  2      3     3                       Avatar: The Way of Water
#  3      4     1                                        Titanic
#  4      5     3                   Star Wars: The Force Awakens
#  5      6     4                         Avengers: Infinity War
#  6      7     6                        Spider-Man: No Way Home
#  7      8     3                                 Jurassic World
#  8      9     7                                  The Lion King
#  9     10     3                                   The Avengers
#  10    11     4                                      Furious 7
#  11    12    11                              Top Gun: Maverick
#  12    13    10                                      Frozen II
#  13    14    14                                       Barbie †
# ...

# %%
type(df)
# Out:
# list

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price=df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-15-5f86cc00013c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
df_drink=df[df.item_price<1.1]

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df[df.item_name=='Steak Burrrito']
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
df[df.item_name=='Steak Burrrito'].choice_description.value_counts()
# Out:
# Series([], Name: choice_description, dtype: int64)

# %%
df[(df.item_price < 10)&(df.item_name =='Chicken Bowl')]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
df=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.star_rating>=8.0)&(df.content_rating=='PG')]
# Out:
#      star_rating                                              title  \
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                          Star Wars
# 30           8.6                                      Spirited Away
# 32           8.6                                         Casablanca
# 37           8.6                            Raiders of the Lost Ark
# 47           8.5                                   Taare Zameen Par
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 54           8.5                                 Back to the Future
# 80           8.4         Star Wars: Episode VI - Return of the Jedi
# 85           8.4                                 Lawrence of Arabia
# 97           8.4                                          The Sting
# 101          8.3                    Monty Python and the Holy Grail
# 126          8.3                                                 Up
# ...

# %%
df[(df.genre=='Action')]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df[df.actors_list.str.contains('Grace Kelly')]
# Out:
#      star_rating              title content_rating    genre  duration  \
# 38           8.6        Rear Window       APPROVED  Mystery       112
# 171          8.2  Dial M for Murder             PG    Crime       105
# 236          8.1          High Noon             PG  Western        85
# 866          7.5   To Catch a Thief       APPROVED  Mystery       106
#
#                                            actors_list
# 38   [u'James Stewart', u'Grace Kelly', u'Wendell C...
# 171  [u'Ray Milland', u'Grace Kelly', u'Robert Cumm...
# 236  [u'Gary Cooper', u'Grace Kelly', u'Thomas Mitc...
# 866  [u'Cary Grant', u'Grace Kelly', u'Jessie Royce...

# %%
df[df.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
new=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
new
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
new.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
new.dropna(subset=['City','Shape Reported' ],how='all').shape
# Out:
# (18237, 5)

# %%
new['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
new['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks[drinks.continent=='Asia'].beer_servings.agg(['mean','min','max'])
#on same line
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
